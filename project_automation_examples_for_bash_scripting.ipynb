# %% [markdown]
# As mentioned in the Search_about_bash_scripting.ipynb file here are some automation examples for bash scripting:

# %% [markdown]
# First project:
#
# The code:
#
# ![first.png](data:image/png;base64,...)
#
# The output in bash:
#
# ![1.png](data:image/png;base64,...)

# %% [markdown]
# Second project:
#
# The code:
#
# ![second.png](data:image/png;base64,...)
#
# The output in bash:
#
# ![2.png](data:image/png;base64,...)

# %% [markdown]
# Third project:
#
# The code:
#
# ![third.png](data:image/png;base64,...)
#
# The output in bash:
#
# ![3.png](data:image/png;base64,...)

# %% [markdown]
# Fourth project:
#
# The code:
#
# ![fourth.png](data:image/png;base64,...)
#
# The output in bash:
#
# ![4.png](data:image/png;base64,...)

# %% [markdown]
# Fifth project:
#
# The code:
#
# ![fifth.png](data:image/png;base64,...)
#
# The output in bash:
#
# ![5.png](data:image/png;base64,...)

# %% [markdown]
# Sixth project:
#
# The code:
#
# ![sixth.png](data:image/png;base64,...)
#
# The output:
#
# ![6.png](data:image/png;base64,...)

# %% [markdown]
# Seventh project:
#
# The code:
#
# ![seventh.png](data:image/png;base64,...)
#
# The output:
#
# ![7.png](data:image/png;base64,...)

# %% [markdown]
# Eigth project:
#
# The code:
#
# ![eighth.png](data:image/png;base64,...)
#
# The output in bash:
#
# ![8.png](data:image/png;base64,...)
